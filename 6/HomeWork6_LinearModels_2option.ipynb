# %% [markdown]
# <a href="https://colab.research.google.com/github/MariiaSam/data_science/blob/main/HomeWork6_LinearModels_2option.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/Housing.csv'
df = pd.read_csv(file_path)
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# # ***1. Функція гіпотези лінійної регресії у векторному вигляді***

# %%
def hypothesis(X, w):
    return np.dot(X, w)

# X — це матриця вхідних даних
# w — вектор ваг (параметрів регресії (w0, w1, w2, ...))
#  Повертає вектор прогнозованих значень

# %% [markdown]
# # ***2. Функція для обчислення функції втрат у векторному вигляді***
#
# **(Mean Squared Error, MSE)**

# %%
def compute_cost(X, y, w):
    m = len(y)
    error = hypothesis(X, w)
    cost = error - y
    return np.sum(cost ** 2) / (2 * m)

#  m = len(y)   кількість прикладів
#  y - вектор цільових значень розмірністю (m, 1), де m - кількість прикладів
# Повертає значення функції втрат (середньоквадратична помилка)

# %% [markdown]
# # ***3. Один крок градієнтного спуску***
#
# ---

# %%
def gradient_step(X, y, w, alpha=0.000001):
    m = len(y)
    error = hypothesis(X, w) - y
    gradient = (1 / m) * np.dot(X.T, error)
    w = w - alpha * gradient
    return w

# %% [markdown]
# # ***3. знайдіть найкращі параметри для датасету використовуючи написані вами функції, прогнозуючу ціну на будинок залежно від площі, кількості ванних кімнат та кількості спалень***

# %%
def gradient_descent(X, y, w, alpha, num_iters):
    cost_history = []

    for i in range(num_iters):
        w = gradient_step(X, y, w, alpha)
        cost = compute_cost(X, y, w)
        cost_history.append(cost)

    return w, cost_history

# %% [markdown]
# **аналітичного рішення;**

# %%
def analytical_solution(X, y):
    X_transpose = np.transpose(X)
    w = np.linalg.inv(X_transpose.dot(X)).dot(X_transpose).dot(y)
    return w

# %%
x_columns = ['area', 'bathrooms', 'bedrooms']
y_column = 'price'
X = df[x_columns]
y = df[y_column]

model = LinearRegression()
model.fit(X, y)

print(f'Intercept from scikit-learn: {model.intercept_}')
print(f'Coefficients from scikit-learn: {model.coef_}')
# Out:
# Intercept from scikit-learn: -173171.60763263796
# Coefficients from scikit-learn: [3.78762754e+02 1.38604950e+06 4.06820034e+05]

# %% [markdown]
# для перевірки спрогнозованих значень, використайте LinearRegression з бібліотеки scikit-learn та порівняйте результати.
