# %%
import matplotlib.pyplot as plt

# %%
goods = ["Product A", "Product B", "Product C", "Product D"]
sales = [400, 300, 500, 600]

plt.bar(goods, sales, color="coral")
plt.title("Sales by Goods")
plt.xlabel("Goods")
plt.ylabel("Sales")

plt.show()
